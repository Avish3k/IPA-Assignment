# %%
#1
i=1
while(i<=100):
    if("7" in str(i)):
        print(i)
    i=i+1
# Out:
# 7
# 17
# 27
# 37
# 47
# 57
# 67
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 87
# 97

# %%
#2
n=int(input("enter a number"))
num=n
sum=0
while(num!=0):
    d=num%10
    sum=(sum*10)+d
    num=num//10
if(sum>n):
    print("rev is greater")
else:
    print("actual is greater")
# Out:
# actual is greater

# %%
#3
n=int(input("enter a number"))
num=n
sum=0
while(num!=0):
    d=num%10
    sum+=d
    num=num//10
print(sum)
# Out:
# 11

# %%
#4
n=int(input("enter a number"))
num=n
e=0
o=0
while(num!=0):
    d=num%10
    if(d%2==0):
        e+=1
    elif(d%2!=0):
        o+=1
    num=num//10
print("no of even are",e)
print("no of odd are",o)
# Out:
# no of even are 4
# no of odd are 0

# %%
#5
n=int(input("enter a number"))
num=n
sum=0
while(num!=0):
    d=num%10
    sum=(sum*10)+d
    num=num//10
if(sum==n):
    print("pallindrome")
else:
    print("not pallindrome")
# Out:
# pallindrome

# %%
#6
a=3
u="avi"
p=1234
i=3
while(i!=0):
    u2=input("enter username")
    n=int(input("enter pin"))
    if(n==p and u==u2):
        print("login success")
        break
    elif(n!=p or u!=u2 and i!=0):
        print(i-1, "attemp left")
    elif(i==0):
        print("login failed")
    i=i-1
# Out:
# login success

# %%
#without args
def without():
    print("hello")
without()
# Out:
# hello

# %%
#with args
def add(a,b):
    c=a+b
    return c
sum=add(20,80)
print(sum)
# Out:
# 100

# %%
#7
n=input("enter number")
s=input("enter number for search")
l=len(n)
c=0
i=0
while(i!=l):
    if(s==n[i]):
        c=c+1
    i=i+1
print(c)
# Out:
# 4

# %%
#8
s=0
n=0
while(s<=100):
    n=int(input("enter number"))
    s+=n
print("Number exceeded")
print(s-n)
# Out:
# Number exceeded
# 100

# %%
def evod(n):
    num=n
    e=0
    o=0
    while(num!=0):
        d=num%10
        if(d%2==0):
            e+=1
        elif(d%2!=0):
            o+=1
        num=num//10
    print("no of even are",e)
    print("no of odd are",o)
evod(845236)
# Out:
# no of even are 4
# no of odd are 2

# %%
import logging
import time
def pallin(n):
    print(time)
    num=n
    sum=0
    while(num!=0):
        d=num%10
        sum=(sum*10)+d
        num=num//10
    if(sum==n):
        logging.info("pallindrome")
    else:
        logging.info("not pallindrome")
pallin(515)
# Out:
# INFO:root:pallindrome
