# %%
fh=open("fh.txt",'w+')

# %%
fh.write("Hello my name is Avishek")
# Out:
# 24

# %%
fh.readline()
# Out:
# ''

# %%
fh.seek(0)
fh.readline()
# Out:
# 'Hello my name is Avishek'

# %%
fh.readlines()
# Out:
# []

# %%
fh.close()

# %%
fh=open("fh.txt","a")

# %%
fh.writelines(["Hello world \n", "Python Programming \n","HIT Haldia \n"])

# %%
fh.close()

# %%
with open('fh.txt',"r") as f:
    words=f.read().split()
    print(len(words))
# Out:
# 10

# %%
with open('fh.txt',"r") as f:
    word=f.read().split()
uw=set(word)    
print(len(uw))
type(word)
# Out:
# 10
# list

# %%
with open('fh.txt', "r") as f:
    words = f.read().split()

d = {}

for word in words:
    if word in d:
        d[word] += 1
    else:
        d[word] = 1
print(d)
# Out:
# {'Hello': 1, 'my': 1, 'name': 1, 'is': 1, 'AvishekHello': 1, 'world': 1, 'Python': 1, 'Programming': 1, 'HIT': 1, 'Haldia': 1}

# %%
data={"Name":"Avishek","Age":23,"Course":"MCA"}

# %%
import json
with open("json.json",'w') as f:
    json.dump(data,f)

# %%
import json
with open("json.json",'r+') as f:
    data=json.load(f)
print(data)
# Out:
# {'Name': 'Avishek', 'Age': 23, 'Course': 'MCA'}

# %%
data2={"Name":"Avishek2","Age":232,"Course":"MCA2"}

# %%
import json
with open("json.json",'r+') as f:
    json.dump(data2,f)

# %%
with open("json.json","r") as f:
    d=json.load(f)
print(d)
# Out:
# {'Name': 'Avishek2', 'Age': 232, 'Course': 'MCA2'}

# %%
import csv 
with open("data.csv","w",newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["Name","Age","Course"])
    writer.writerow(["Avishek","23","MCA"])

# %%
r=["Name","Age","Course"],["Avishek","23","MCA"],["Akash","23","CSE"],["Sisu","24","MBA"]
with open("data.csv","w",newline="") as file:
    writer=csv.writer(file)
    #in single command can write multiple rows :writerows
    writer.writerows(r)
