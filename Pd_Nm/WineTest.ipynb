# %%
import pandas as pd

# %%
df = pd.read_csv('WineQT.csv')

# %%
s=pd.Series([10,20,30])
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s+5
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
print(type(s))
# Out:
# <class 'pandas.core.series.Series'>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.Series([10,20,30], index = ["a","b","c"])
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series({"a":1,"b":2})
# Out:
# a    1
# b    2
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.size
# Out:
# 3

# %%
s.dtype
# Out:
# dtype('int64')

# %%
#mean/average
s.mean()
# Out:
# np.float64(20.0)

# %%
#maximun
s.max()
# Out:
# np.int64(30)

# %%
#minimum
s.min()
# Out:
# np.int64(10)

# %%
#standard deviation
s.std()
# Out:
# np.float64(10.0)

# %%
#frequency count
s.value_counts()
# Out:
# 10    1
# 20    1
# 30    1
# Name: count, dtype: int64

# %%
a=pd.DataFrame([1,2],[3,4])
print(a)
type(a)
# Out:
#    0
# 3  1
# 4  2
# pandas.core.frame.DataFrame

# %%
pd.DataFrame({'A':[1,2],'B':[3,4]})
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2

# %%
df.head(-1142)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0

# %%
df.tail(1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1142     10.2        5  1597

# %%
#random 5 sample data
df.sample(5)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 797           10.0             0.430         0.33             2.7      0.095
# 877            6.5             0.670         0.00             4.3      0.057
# 776            8.4             0.340         0.42             2.1      0.072
# 519            6.4             0.865         0.03             3.2      0.071
# 979            7.5             0.570         0.02             2.6      0.077
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 797                 28.0                  89.0  0.99840  3.22       0.68
# 877                 11.0                  20.0  0.99488  3.45       0.56
# 776                 23.0                  36.0  0.99392  3.11       0.78
# 519                 27.0                  58.0  0.99500  3.61       0.49
# 979                 11.0                  35.0  0.99557  3.36       0.62
#
#      alcohol  quality    Id
# 797     10.0        5  1128
# ...

# %%
df.sample(3,ignore_index=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.6              0.58         0.02             2.4      0.069
# 1            7.5              0.57         0.02             2.6      0.077
# 2            7.2              0.33         0.33             1.7      0.061
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 19.0                  40.0  0.99387  3.38       0.66
# 1                 11.0                  35.0  0.99557  3.36       0.62
# 2                  3.0                  13.0  0.99600  3.23       1.10
#
#    alcohol  quality    Id
# 0     12.6        6  1335
# 1     10.8        6  1379
# 2     10.0        8  1403

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.size
# Out:
# 14859

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.describe(include='float')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.describe(include='int')
# Out:
#            quality           Id
# count  1143.000000  1143.000000
# mean      5.657043   804.969379
# std       0.805824   463.997116
# min       3.000000     0.000000
# 25%       5.000000   411.000000
# 50%       6.000000   794.000000
# 75%       6.000000  1209.500000
# max       8.000000  1597.000000

# %%
#shows datatypes
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.alcohol.dtype
# Out:
# dtype('float64')

# %%
#check datatypes of variable having space
df["fixed acidity"].dtype
# Out:
# dtype('float64')

# %%
#datatypes of only interger
df.select_dtypes(include='int').columns
# Out:
# Index(['quality', 'Id'], dtype='object')

# %%
#datatypes of types excluding interger
df.select_dtypes(exclude='int').columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
df.iloc[0:2,0:4]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar
# 0            7.4              0.70          0.0             1.9
# 1            7.8              0.88          0.0             2.6

# %%
df['fixed acidity'][0]
# Out:
# np.float64(7.4)

# %%
df.iat[2,1]
# Out:
# np.float64(0.76)

# %%
#missing values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
#drops the nan values
df.dropna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#filling nan values
df.fillna(0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#filling nan values with mean
df.fillna(df.mean)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#check duplicates
df.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1138    False
# 1139    False
# 1140    False
# 1141    False
# 1142    False
# Length: 1143, dtype: bool>

# %%
#drop duplicate without inplace the process is temporary
df.drop_duplicates(inplace=True)

# %%
#sortd by column alcohol
df.sort_values(by="alcohol")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 388            14.3              0.31         0.74             1.8      0.075
# 368            10.4              0.61         0.49             2.1      0.200
# 1023           10.0              0.38         0.38             1.6      0.169
# 263             7.9              0.24         0.40             1.6      0.056
# 1051            9.9              0.50         0.50            13.8      0.205
# ...             ...               ...          ...             ...        ...
# 589             4.9              0.42         0.00             2.1      0.048
# 419             5.0              0.42         0.24             2.0      0.060
# 98              5.2              0.34         0.00             1.8      0.050
# 96              5.2              0.34         0.00             1.8      0.050
# 462            15.9              0.36         0.65             7.5      0.096
#
# ...

# %%
#sample 5 give 5 random rows and .sort arranges in ascending order
df.sample(5).sort_index()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 30             7.5              0.49         0.20             2.6      0.332
# 668            8.3              0.28         0.48             2.1      0.093
# 696            7.7              0.39         0.12             1.7      0.097
# 781            9.1              0.30         0.41             2.0      0.068
# 998            8.2              0.24         0.34             5.1      0.062
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 30                   8.0                  14.0  0.99680  3.21       0.90
# 668                  6.0                  12.0  0.99408  3.26       0.62
# 696                 19.0                  27.0  0.99596  3.16       0.49
# 781                 10.0                  24.0  0.99523  3.27       0.85
# 998                  8.0                  22.0  0.99740  3.22       0.94
#
#      alcohol  quality    Id
# 30      10.5        6    42
# ...

# %%
#again sample give 7 random rows, ignore index makes the index start from 0 instead of their actual index
df.sample(7,ignore_index=True).sort_index(ascending=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           12.6             0.410         0.54             2.8      0.103
# 1            6.2             0.785         0.00             2.1      0.060
# 2            6.2             0.460         0.29             2.1      0.074
# 3            7.8             0.630         0.48             1.7      0.100
# 4           11.8             0.380         0.55             2.1      0.071
# 5           10.0             0.430         0.33             2.7      0.095
# 6            8.0             0.715         0.22             2.3      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 19.0                  41.0  0.99939  3.21       0.76
# 1                  6.0                  13.0  0.99664  3.59       0.61
# 2                 32.0                  98.0  0.99578  3.33       0.62
# 3                 14.0                  96.0  0.99610  3.19       0.62
# ...

# %%
#check next
df.sample(5).reset_index()
# Out:
#    index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    352           10.7              0.35         0.53             2.6
# 1     19            7.6              0.41         0.24             1.8
# 2    682            9.0              0.40         0.43             2.4
# 3    840            9.1              0.40         0.57             4.6
# 4    155            7.5              0.49         0.19             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.070                  5.0                  16.0  0.99720  3.15
# 1      0.080                  4.0                  11.0  0.99620  3.28
# 2      0.068                 29.0                  46.0  0.99430  3.20
# 3      0.080                  6.0                  20.0  0.99652  3.28
# 4      0.076                 10.0                  44.0  0.99570  3.39
#
#    sulphates  alcohol  quality    Id
# 0       0.65     11.0        8   498
# ...

# %%
#check index
df.sample(5).reset_index(drop=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           10.0             0.690         0.11             1.4      0.084
# 1            9.1             0.765         0.04             1.6      0.078
# 2            8.0             0.450         0.23             2.2      0.094
# 3            9.3             0.500         0.36             1.8      0.084
# 4            9.3             0.655         0.26             2.0      0.096
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  8.0                  24.0  0.99578  2.88       0.47
# 1                  4.0                  14.0  0.99800  3.29       0.54
# 2                 16.0                  29.0  0.99620  3.21       0.49
# 3                  6.0                  17.0  0.99704  3.27       0.77
# 4                  5.0                  35.0  0.99738  3.25       0.42
#
#    alcohol  quality    Id
# 0      9.7        5  1470
# 1      9.7        4   704
# ...

# %%
#correlation
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
#unique
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
#no. of unique values
df["quality"].nunique()
# Out:
# 6

# %%
df["fixed acidity"].unique()
# Out:
# array([ 7.4,  7.8, 11.2,  7.9,  7.3,  6.7,  5.6,  8.5,  7.6,  6.9,  6.3,
#         7.1,  8.3,  5.2,  8.1,  8.8,  7.5,  4.6,  7.7,  6.6,  8.6, 10.2,
#         7. ,  7.2,  8. ,  6.8,  6.2,  9.3,  5. ,  8.4, 10.1,  9.4,  8.2,
#         5.8,  9.2,  8.9,  6.4, 11.5,  9.6, 12.8,  9.7,  8.7, 12. , 15. ,
#        10.8, 11.1, 10. , 12.5, 10.3, 11.4,  9.9, 11.6, 10.4, 13.3, 10.6,
#         9. ,  9.8, 13.4, 11.9, 10.9, 13.8,  9.1, 13.5,  6.1, 10.5, 12.6,
#        13.7,  9.5, 12.2, 12.3, 15.6,  5.3, 11.3, 13. ,  6.5, 10.7, 12.9,
#        14.3, 12.4, 15.5, 12.7, 13.2, 15.9,  5.1, 11.8,  4.9,  5.9, 11.7,
#         5.4,  5.7,  6. ])

# %%
df["quality"].value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
#returns in true or false
df["quality"]>5
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1138     True
# 1139     True
# 1140    False
# 1141     True
# 1142    False
# Name: quality, Length: 1143, dtype: bool

# %%
#returns the actual values
df[df["quality"]>5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 12              8.5              0.28         0.56             1.8      0.092
# 13              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 1136            6.3              0.55         0.15             1.8      0.077
# 1137            5.4              0.74         0.09             1.7      0.089
# 1138            6.3              0.51         0.13             2.3      0.076
# 1139            6.8              0.62         0.08             1.9      0.068
# 1141            5.9              0.55         0.10             2.2      0.062
#
# ...

# %%
#checking 2 statements at once
df[(df["quality"]>5) & (df["alcohol"]>10)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 12              8.5             0.280         0.56             1.8      0.092
# 26              7.8             0.600         0.14             2.4      0.086
# 30              7.5             0.490         0.20             2.6      0.332
# 38              7.6             0.510         0.15             2.8      0.110
# 48              8.0             0.705         0.05             1.9      0.074
# ...             ...               ...          ...             ...        ...
# 1135            5.8             0.610         0.11             1.8      0.066
# 1136            6.3             0.550         0.15             1.8      0.077
# 1137            5.4             0.740         0.09             1.7      0.089
# 1138            6.3             0.510         0.13             2.3      0.076
# 1141            5.9             0.550         0.10             2.2      0.062
#
# ...

# %%
#increasing alcohol by 10 percent
df.alcohol*=1.10

# %%
def rating(quality):
    if quality>5:
        return "good"
    else:
        return "bad"

# %%
df['quality review']=df['quality'].apply(rating)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id quality review
# 0    10.34        5   0            bad
# ...

# %%
#creates a new file without index
df.to_csv("Wine.csv",index=False,header=False)

# %%
df['quality_level']=df["quality"].map({3:'Very Bad', 4:'Bad',5:'Good',6:'Very Good',7:'Nice',8:'Excellent'})
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id quality review quality_level
# ...

# %%
df["quality_level"].unique()
# Out:
# array(['Good', 'Very Good', 'Nice', 'Bad', 'Excellent', 'Very Bad'],
#       dtype=object)

# %%
df["quality_level"].map({"Good":"Good1","Very Good":"VG2"})
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.rename(columns={"fixed acidity":"Acidity"},inplace=False)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id quality review quality_level
# ...

# %%
df1=pd.read_csv("wine_data.csv")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         220 non-null    float64
#  1   volatile acidity      220 non-null    float64
#  2   citric acid           220 non-null    float64
#  3   residual sugar        220 non-null    float64
#  4   chlorides             220 non-null    float64
#  5   free sulfur dioxide   220 non-null    float64
#  6   total sulfur dioxide  220 non-null    float64
#  7   density               220 non-null    float64
#  8   pH                    220 non-null    float64
#  9   sulphates             220 non-null    float64
#  10  alcohol               220 non-null    float64
#  11  quality               220 non-null    int64
#  12  Id                    220 non-null    int64
#  13  name                  220 non-null    object
# ...

# %%
df1.name
# Out:
# 0                                WineA
# 1                                WineB
# 2                                WineC
# 3                                WineD
# 4            Weingut Syrah Reserve 575
#                     ...
# 215           Bodega Pinot Classic 513
# 216       Castello Merlot Grand Cru 41
# 217    Bodega Chardonnay Grand Cru 257
# 218       Chateau Cabernet Special 857
# 219       Bodega Sauvignon Classic 591
# Name: name, Length: 220, dtype: object

# %%
df1.name.str.upper()
# Out:
# 0                                WINEA
# 1                                WINEB
# 2                                WINEC
# 3                                WINED
# 4            WEINGUT SYRAH RESERVE 575
#                     ...
# 215           BODEGA PINOT CLASSIC 513
# 216       CASTELLO MERLOT GRAND CRU 41
# 217    BODEGA CHARDONNAY GRAND CRU 257
# 218       CHATEAU CABERNET SPECIAL 857
# 219       BODEGA SAUVIGNON CLASSIC 591
# Name: name, Length: 220, dtype: object

# %%
df1.name.str.capitalize()
# Out:
# 0                                Winea
# 1                                Wineb
# 2                                Winec
# 3                                Wined
# 4            Weingut syrah reserve 575
#                     ...
# 215           Bodega pinot classic 513
# 216       Castello merlot grand cru 41
# 217    Bodega chardonnay grand cru 257
# 218       Chateau cabernet special 857
# 219       Bodega sauvignon classic 591
# Name: name, Length: 220, dtype: object

# %%
df1.name.str.title()
# Out:
# 0                                Winea
# 1                                Wineb
# 2                                Winec
# 3                                Wined
# 4            Weingut Syrah Reserve 575
#                     ...
# 215           Bodega Pinot Classic 513
# 216       Castello Merlot Grand Cru 41
# 217    Bodega Chardonnay Grand Cru 257
# 218       Chateau Cabernet Special 857
# 219       Bodega Sauvignon Classic 591
# Name: name, Length: 220, dtype: object

# %%
pd.to_datetime(df1.date)
# Out:
# 0     2023-01-10
# 1     2023-02-15
# 2     2023-03-20
# 3     2023-04-25
# 4     2023-02-12
#          ...
# 215   2024-10-08
# 216   2024-06-03
# 217   2022-02-22
# 218   2022-02-12
# 219   2022-03-24
# Name: date, Length: 220, dtype: datetime64[ns]

# %%
df1['date']=pd.to_datetime(df1['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
#  13  quality review        1143 non-null   object
# ...

# %%
df1.date.dt.year
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 215    2024
# 216    2024
# 217    2022
# 218    2022
# 219    2022
# Name: date, Length: 220, dtype: int32

# %%
df1['Year']=df1['date'].dt.year

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         220 non-null    float64
#  1   volatile acidity      220 non-null    float64
#  2   citric acid           220 non-null    float64
#  3   residual sugar        220 non-null    float64
#  4   chlorides             220 non-null    float64
#  5   free sulfur dioxide   220 non-null    float64
#  6   total sulfur dioxide  220 non-null    float64
#  7   density               220 non-null    float64
#  8   pH                    220 non-null    float64
#  9   sulphates             220 non-null    float64
#  10  alcohol               220 non-null    float64
#  11  quality               220 non-null    int64
#  12  Id                    220 non-null    int64
#  13  name                  220 non-null    object
# ...

# %%
df1.loc[5]
# Out:
# fixed acidity                                  8.72
# volatile acidity                               0.56
# citric acid                                    0.34
# residual sugar                                  0.8
# chlorides                                     0.059
# free sulfur dioxide                            22.3
# total sulfur dioxide                           59.8
# density                                     0.99571
# pH                                             3.35
# sulphates                                      0.79
# alcohol                                        9.79
# quality                                           4
# Id                                                6
# name                    Bodega Riesling Special 559
# date                            2024-05-09 00:00:00
# Year                                           2024
# Name: 5, dtype: object

# %%
df1.loc[len(df1)] = [9, .23, .55, .9, .047, 24, 61, .84569, 4.10, .47, 10.45, 5, 7,"Italiano Del Wine", "2024-02-05 00:00:00", 2024]

# %%
df1.head(-1)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             8.50              0.28         0.56             1.8      0.092
# 1             8.00              0.59         0.16             1.8      0.065
# 2             9.60              0.32         0.47             1.4      0.056
# 3            12.80              0.30         0.74             2.6      0.095
# 4             9.91              0.45         0.49             2.8      0.053
# ..             ...               ...          ...             ...        ...
# 215          10.62              0.38         0.41             3.0      0.072
# 216          10.21              0.17         0.60             2.5      0.059
# 217          11.29              0.36         0.46             2.8      0.082
# 218           9.21              0.36         0.51             2.6      0.082
# 219          10.02              0.21         0.47             1.8      0.050
#
# ...

# %%
#delete particular record
df.drop(index=11,inplace=True)

# %%
df3=df.drop(columns='pH')
df3
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df1["High_Alcohol"]=df.alcohol >=10
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.50              0.28         0.56             1.8      0.092
# 1           8.00              0.59         0.16             1.8      0.065
# 2           9.60              0.32         0.47             1.4      0.056
# 3          12.80              0.30         0.74             2.6      0.095
# 4           9.91              0.45         0.49             2.8      0.053
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 103.0  0.99690  3.30       0.75
# 1                  3.0                  16.0  0.99620  3.42       0.92
# 2                  9.0                  24.0  0.99695  3.22       0.82
# 3                  9.0                  28.0  0.99940  3.20       0.77
# 4                 21.9                  60.5  0.99683  3.31       0.90
#
#    alcohol  quality   Id                       name                 date  \
# ...

# %%
df1["Wine_Type"]="Red Wine"
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.50              0.28         0.56             1.8      0.092
# 1           8.00              0.59         0.16             1.8      0.065
# 2           9.60              0.32         0.47             1.4      0.056
# 3          12.80              0.30         0.74             2.6      0.095
# 4           9.91              0.45         0.49             2.8      0.053
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 103.0  0.99690  3.30       0.75
# 1                  3.0                  16.0  0.99620  3.42       0.92
# 2                  9.0                  24.0  0.99695  3.22       0.82
# 3                  9.0                  28.0  0.99940  3.20       0.77
# 4                 21.9                  60.5  0.99683  3.31       0.90
#
#    alcohol  quality   Id                       name                 date  \
# ...

# %%
#merge and concat
data1={"Name":['A','B','C'],'Age':[22,25,32],"Salary":[10000,15000,30000]}

data2={"Name":['D','E','F','A'],'Age':[29,31,39,41],"Salary":[210000,115000,430000,450001]}

# %%
newdf1=pd.DataFrame(data1)
newdf2=pd.DataFrame(data2)

# %%
newdf1.head()
# Out:
#   Name  Age  Salary
# 0    A   22   10000
# 1    B   25   15000
# 2    C   32   30000

# %%
newdf2.head()
# Out:
#   Name  Age  Salary
# 0    D   29  210000
# 1    E   31  115000
# 2    F   39  430000
# 3    A   41  450001

# %%
pd.concat([newdf1,newdf2],ignore_index=True)
# Out:
#   Name  Age  Salary
# 0    A   22   10000
# 1    B   25   15000
# 2    C   32   30000
# 3    D   29  210000
# 4    E   31  115000
# 5    F   39  430000
# 6    A   41  450001

# %%
pd.concat([newdf1,newdf2],ignore_index=True,axis=1)
# Out:
#      0     1        2  3   4       5
# 0    A  22.0  10000.0  D  29  210000
# 1    B  25.0  15000.0  E  31  115000
# 2    C  32.0  30000.0  F  39  430000
# 3  NaN   NaN      NaN  A  41  450001

# %%
newdata=pd.concat([newdf1,newdf2],ignore_index=True,axis=False)
newdata.head(10)
# Out:
#   Name  Age  Salary
# 0    A   22   10000
# 1    B   25   15000
# 2    C   32   30000
# 3    D   29  210000
# 4    E   31  115000
# 5    F   39  430000
# 6    A   41  450001

# %%
newdata.head(10)
# Out:
#   Name  Age  Salary
# 0    A   22   10000
# 1    B   25   15000
# 2    C   32   30000
# 3    D   29  210000
# 4    E   31  115000
# 5    F   39  430000
# 6    A   41  450001

# %%
pd.merge(newdf1,newdf2, on='Age',how='outer')
# Out:
#   Name_x  Age  Salary_x Name_y  Salary_y
# 0      A   22   10000.0    NaN       NaN
# 1      B   25   15000.0    NaN       NaN
# 2    NaN   29       NaN      D  210000.0
# 3    NaN   31       NaN      E  115000.0
# 4      C   32   30000.0    NaN       NaN
# 5    NaN   39       NaN      F  430000.0
# 6    NaN   41       NaN      A  450001.0
